# %% [markdown]
# # Train, tune, and deploy a custom ML model using the Time Series Forecasting (RNN) Algorithm from AWS Marketplace

# %% [markdown]
# The [Time Series Forecasting (RNN) Algorithm from AWS Marketplace]() performs time series forecasting with a multi-layer Recurrent Neural Network (RNN).
# It implements both training and inference from CSV data and supports both CPU and GPU instances.
# The training and inference Docker images were built by extending the PyTorch 2.1.0 Python 3.10 SageMaker containers.
#
# **Model Overview**
#
# The model is a stack of RNN layers with either LSTM or GRU cells.
# Each RNN layer is followed by an activation layer and a dropout layer.
# The model is trained by minimizing the negative Gaussian log-likelihood and outputs the predicted mean and standard deviation of each target time series at each future time step.
#
# <img src=https://fg-research-assets.s3.eu-west-1.amazonaws.com/rnn-diagram.png style="width:80%;margin-top:20px;margin-bottom:20px"/>
#
# *LSTM and GRU cells (source: [doi:10.48550/arXiv.1412.3555](https://doi.org/10.48550/arXiv.1412.3555))*
#
# This sample notebook shows you how to train a custom ML model using the [Time Series Forecasting (RNN) Algorithm from AWS Marketplace]().
#
# **Note: This is a reference notebook and it cannot run unless you make the changes suggested in the notebook.**

# %% [markdown]
# ## Pre-requisites
# 1. This notebook contains elements which render correctly in Jupyter interface. Open this notebook from an Amazon SageMaker Notebook Instance or Amazon SageMaker Studio.
# 1. Ensure that IAM role used has **AmazonSageMakerFullAccess**
# 1. Some hands-on experience using [Amazon SageMaker](https://aws.amazon.com/sagemaker/).
# 1. To use this algorithm successfully, ensure that:
#     1. Either your IAM role has these three permissions and you have authority to make AWS Marketplace subscriptions in the AWS account used:
#         1. **aws-marketplace:ViewSubscriptions**
#         1. **aws-marketplace:Unsubscribe**
#         1. **aws-marketplace:Subscribe**
#     2. or your AWS account has a subscription to the [Time Series Forecasting (RNN) Algorithm from AWS Marketplace]().

# %% [markdown]
# ## Contents
# 1. [Subscribe to the algorithm](#1.-Subscribe-to-the-algorithm)
# 1. [Prepare dataset](#2.-Prepare-dataset)
# 	1. [Dataset format expected by the algorithm](#A.-Dataset-format-expected-by-the-algorithm)
# 	1. [Configure and visualize train and test dataset](#B.-Configure-and-visualize-train-and-test-dataset)
# 	1. [Upload datasets to Amazon S3](#C.-Upload-datasets-to-Amazon-S3)
# 1. [Train a machine learning model](#3:-Train-a-machine-learning-model)
# 	1. [Set up environment](#3.1-Set-up-environment)
# 	1. [Train a model](#3.2-Train-a-model)
# 1. [Deploy model and verify results](#4:-Deploy-model-and-verify-results)
#     1. [Deploy trained model](#A.-Deploy-trained-model)
#     1. [Create input payload](#B.-Create-input-payload)
#     1. [Perform real-time inference](#C.-Perform-real-time-inference)
#     1. [Visualize output](#D.-Visualize-output)
#     1. [Calculate relevant metrics](#E.-Calculate-relevant-metrics)
#     1. [Delete the endpoint](#F.-Delete-the-endpoint)
# 1. [Tune your model! (optional)](#5:-Tune-your-model!-(optional))
# 	1. [Tuning Guidelines](#A.-Tuning-Guidelines)
# 	1. [Define Tuning configuration](#B.-Define-Tuning-configuration)
# 	1. [Run a model tuning job](#C.-Run-a-model-tuning-job)
# 1. [Perform Batch inference](#6.-Perform-Batch-inference)
# 1. [Clean-up](#7.-Clean-up)
# 	1. [Delete the model](#A.-Delete-the-model)
# 	1. [Unsubscribe to the listing (optional)](#B.-Unsubscribe-to-the-listing-(optional))
#
#
# ## Usage instructions
# You can run this notebook one cell at a time (by using Shift+Enter for running a cell).

# %% [markdown]
# ## 1. Subscribe to the algorithm

# %% [markdown]
# To subscribe to the algorithm:
# 1. Open the algorithm listing page.
# 1. On the AWS Marketplace listing, click on the **Continue to subscribe** button.
# 1. On the **Subscribe to this software** page, review and click on **"Accept Offer"** if you agree with EULA, pricing, and support terms.
# 1. Once you click on the **Continue to configuration** button and then choose a **region**, you will see a **Product ARN**. This is the algorithm ARN that you need to specify while training a custom ML model. **Copy the ARN corresponding to your region and specify the same in the following cell.**

# %%
# SageMaker algorithm ARN, replace the placeholder below with your AWS Marketplace ARN
algo_arn = "arn:aws:sagemaker:<...>"

# %% [markdown]
# ## 2. Prepare dataset

# %%
import io
import datetime
import boto3
import sagemaker
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error, mean_absolute_error
# Out:
# sagemaker.config INFO - Not applying SDK defaults from location: /etc/xdg/sagemaker/config.yaml
# sagemaker.config INFO - Not applying SDK defaults from location: /home/ec2-user/.config/sagemaker/config.yaml

# %%
# SageMaker session
sagemaker_session = sagemaker.Session()

# S3 bucket
bucket = sagemaker_session.default_bucket()

# EC2 instance
instance_type = "ml.m5.2xlarge"

# fixed hyperparameters
context_length = 200     # number of timesteps used as input
prediction_length = 100  # number of timesteps to output

# %% [markdown]
# ### A. Dataset format expected by the algorithm

# %% [markdown]
# The training and validation datasets should be provided as CSV files.
# Each column represents a time series, while each row represents a time step.
# All the time series should have the same length and should not contain missing values.
# The column headers should be formatted as follows:
#
# - The column names of the (mandatory) target time series should start with `"y"` (e.g. `"y1"`, `"y2"`, ...).
# - The column names of the (optional) feature time series should start with `"x"` (e.g. `"x1"`, `"x2"`, ...).
#
# If the features are not provided, the algorithm will only use the past values of the target time series as input.
#
# You can find more information about dataset format in the **Usage Information** section of the algorithm listing page.

# %% [markdown]
# ### B. Configure and visualize train and test dataset

# %% [markdown]
# The sample data provided in the algorithm's [GitHub repository](https://github.com/fg-research/rnn-sagemaker) consists of four artificially generated time series including two targets (`"y1"`, `"y2"`) and two features (`"x1"`, `"x2"`). The training dataset contains 1000 samples, while the validation and test datasets contain 500 samples.

# %% [markdown]
# **Training dataset:**

# %%
training_dataset = pd.read_csv("https://raw.githubusercontent.com/fg-research/rnn-sagemaker/master/data/training/train.csv")

# %%
training_dataset.shape
# Out:
# (1000, 4)

# %%
training_dataset.head()
# Out:
#          x1        x2         y1         y2
# 0  0.121642 -0.992107   2.627251 -21.043495
# 1 -0.046251 -0.899425  -3.134639 -20.881941
# 2  0.016789 -0.845949  -3.418829 -16.630003
# 3 -0.020171 -1.000907  -7.383935 -20.160302
# 4 -0.313692 -1.002584 -11.523211 -18.012853

# %%
fig, axs = plt.subplots(nrows=len(training_dataset.columns), ncols=1, sharex=True, figsize=(6, 8))
for i, c in enumerate(training_dataset.columns):
    axs[i].plot(training_dataset[c], color="#7f8ea3", lw=1)
    axs[i].set_title(c, size=10)
    axs[i].set(xlabel="Time", ylabel="Value")
    axs[i].xaxis.set_tick_params(labelbottom=True)
    axs[i].tick_params(axis="both", which="major", labelsize=7)
    axs[i].tick_params(axis="both", which="minor", labelsize=7)
fig.suptitle("Training Dataset")
fig.tight_layout()
fig.show()

# %% [markdown]
# **Validation dataset:**

# %%
validation_dataset = pd.read_csv("https://raw.githubusercontent.com/fg-research/rnn-sagemaker/master/data/training/valid.csv")

# %%
validation_dataset.shape
# Out:
# (500, 4)

# %%
validation_dataset.head()
# Out:
#          x1        x2         y1         y2
# 0 -0.102191 -1.020255  -1.629867 -18.293319
# 1 -0.196894 -0.825729  -5.875837 -15.153669
# 2 -0.103916 -0.909815  -9.099113 -18.314596
# 3 -0.128711 -1.021893 -10.430847 -17.330995
# 4 -0.331239 -0.987491 -15.354902 -15.939409

# %%
fig, axs = plt.subplots(nrows=len(validation_dataset.columns), ncols=1, sharex=True, figsize=(6, 8))
for i, c in enumerate(validation_dataset.columns):
    axs[i].plot(validation_dataset[c], color="#7f8ea3", lw=1)
    axs[i].set_title(c, size=10)
    axs[i].set(xlabel="Time", ylabel="Value")
    axs[i].xaxis.set_tick_params(labelbottom=True)
    axs[i].tick_params(axis="both", which="major", labelsize=7)
    axs[i].tick_params(axis="both", which="minor", labelsize=7)
fig.suptitle("Validation Dataset")
fig.tight_layout()
fig.show()

# %% [markdown]
# ### C. Upload datasets to Amazon S3

# %%
training_data = sagemaker_session.upload_string_as_file_body(
    body=training_dataset.to_csv(index=False),
    bucket=bucket,
    key="data/training/train.csv"
)

# %%
training_data
# Out:
# 's3://sagemaker-eu-west-1-661670223746/data/training/train.csv'

# %%
validation_data = sagemaker_session.upload_string_as_file_body(
    body=validation_dataset.to_csv(index=False),
    bucket=bucket,
    key="data/training/valid.csv"
)

# %%
validation_data
# Out:
# 's3://sagemaker-eu-west-1-661670223746/data/training/valid.csv'

# %% [markdown]
# ## 3. Train a machine learning model

# %% [markdown]
# Now that dataset is available in an accessible Amazon S3 bucket, we are ready to train a machine learning model.

# %% [markdown]
# ### 3.1 Set up environment

# %%
role = sagemaker.get_execution_role()

# %% [markdown]
# ### 3.2 Train a model

# %% [markdown]
# You can find more information about the model's hyperparameters in the **Hyperparameters** section of the algorithm listing page.

# %%
hyperparameters = {
    "context-length": 200,
    "prediction-length": 100,
    "sequence-stride": 1,
    "cell-type": "gru",
    "hidden-size-1": 128,
    "hidden-size-2": 64,
    "hidden-size-3": 0,
    "activation": "lecun",
    "dropout": 0,
    "lr": 0.001,
    "lr-decay": 0.999,
    "batch-size": 64,
    "epochs": 25,
}

# %%
metric_definitions = [
    {"Name": "training_mse", "Regex": "train_mse: ([0-9\\.]+)"},
    {"Name": "validation_mse", "Regex": "valid_mse: ([0-9\\.]+)"},
    {"Name": "training_mae", "Regex": "train_mae: ([0-9\\.]+)"},
    {"Name": "validation_mae", "Regex": "valid_mae: ([0-9\\.]+)"},
    {"Name": "train:mse", "Regex": "train:mse ([0-9\\.]+)"},
    {"Name": "valid:mse", "Regex": "valid:mse ([0-9\\.]+)"},
    {"Name": "train:mae", "Regex": "train:mae ([0-9\\.]+)"},
    {"Name": "valid:mae", "Regex": "valid:mae ([0-9\\.]+)"},
]

# %% [markdown]
# For information on creating an `Estimator` object, see the [documentation](https://sagemaker.readthedocs.io/en/stable/api/training/estimators.html).

# %%
estimator = sagemaker.algorithm.AlgorithmEstimator(
    algorithm_arn=algo_arn,
    base_job_name="rnn-training",
    role=role,
    instance_count=1,
    instance_type=instance_type,
    input_mode="File",
    sagemaker_session=sagemaker_session,
    hyperparameters=hyperparameters,
    metric_definitions=metric_definitions
)

estimator.fit({"training": training_data, "validation": validation_data})
# Out:
# INFO:sagemaker:Creating training-job with name: rnn-training-2024-08-07-13-26-27-266
# 2024-08-07 13:26:27 Starting - Starting the training job...
# 2024-08-07 13:26:46 Starting - Preparing the instances for training...
# 2024-08-07 13:27:13 Downloading - Downloading input data...
# 2024-08-07 13:27:38 Downloading - Downloading the training image..................
# 2024-08-07 13:30:30 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2024-08-07 13:30:44,305 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2024-08-07 13:30:44,306 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:30:44,307 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:30:44,307 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:30:44,307 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:30:44,317 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2024-08-07 13:30:44,319 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2024-08-07 13:30:45,696 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:30:45,696 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:30:45,697 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:30:45,697 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:30:45,708 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:30:45,708 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:30:45,709 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:30:45,709 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:30:45,720 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:30:45,720 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:30:45,720 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:30:45,720 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:30:45,731 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.2xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "activation": "lecun",
#         "batch-size": 64,
#         "cell-type": "gru",
#         "context-length": 200,
#         "dropout": 0.0,
#         "epochs": 25,
#         "hidden-size-1": 128,
#         "hidden-size-2": 64,
#         "hidden-size-3": 0,
#         "lr": 0.001,
#         "lr-decay": 0.999,
#         "prediction-length": 100,
#         "sequence-stride": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.2xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": true,
#     "job_name": "rnn-training-2024-08-07-13-26-27-266",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "training",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "training.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"activation":"lecun","batch-size":64,"cell-type":"gru","context-length":200,"dropout":0.0,"epochs":25,"hidden-size-1":128,"hidden-size-2":64,"hidden-size-3":0,"lr":0.001,"lr-decay":0.999,"prediction-length":100,"sequence-stride":1}
# SM_USER_ENTRY_POINT=training.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.2xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=training
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.2xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"activation":"lecun","batch-size":64,"cell-type":"gru","context-length":200,"dropout":0.0,"epochs":25,"hidden-size-1":128,"hidden-size-2":64,"hidden-size-3":0,"lr":0.001,"lr-decay":0.999,"prediction-length":100,"sequence-stride":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":true,"job_name":"rnn-training-2024-08-07-13-26-27-266","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"training","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"training.py"}
# SM_USER_ARGS=["--activation","lecun","--batch-size","64","--cell-type","gru","--context-length","200","--dropout","0.0","--epochs","25","--hidden-size-1","128","--hidden-size-2","64","--hidden-size-3","0","--lr","0.001","--lr-decay","0.999","--prediction-length","100","--sequence-stride","1"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_ACTIVATION=lecun
# SM_HP_BATCH-SIZE=64
# SM_HP_CELL-TYPE=gru
# SM_HP_CONTEXT-LENGTH=200
# SM_HP_DROPOUT=0.0
# SM_HP_EPOCHS=25
# SM_HP_HIDDEN-SIZE-1=128
# SM_HP_HIDDEN-SIZE-2=64
# SM_HP_HIDDEN-SIZE-3=0
# SM_HP_LR=0.001
# SM_HP_LR-DECAY=0.999
# SM_HP_PREDICTION-LENGTH=100
# SM_HP_SEQUENCE-STRIDE=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python310.zip:/opt/conda/lib/python3.10:/opt/conda/lib/python3.10/lib-dynload:/opt/conda/lib/python3.10/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.10 training.py --activation lecun --batch-size 64 --cell-type gru --context-length 200 --dropout 0.0 --epochs 25 --hidden-size-1 128 --hidden-size-2 64 --hidden-size-3 0 --lr 0.001 --lr-decay 0.999 --prediction-length 100 --sequence-stride 1
# 2024-08-07 13:30:45,731 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-08-07 13:30:45,732 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# --------------------------------------
# Training on 1000 samples.
# --------------------------------------
# --------------------------------------
# Features: ['x1', 'x2']
# Targets: ['y1', 'y2']
# --------------------------------------
# --------------------------------------
# Validating on 500 samples.
# --------------------------------------
# --------------------------------------
# Building the model.
# Number of parameters: 114704
# --------------------------------------
# --------------------------------------
# Training the model.
# epoch: 1, train_mse: 0.13515678 train_mae: 0.29830703 valid_mse: 0.13596287 valid_mae: 0.29854739
# epoch: 2, train_mse: 0.07760652 train_mae: 0.23666339 valid_mse: 0.07904867 valid_mae: 0.23910952
# epoch: 3, train_mse: 0.08602034 train_mae: 0.25455579 valid_mse: 0.08763684 valid_mae: 0.25730661
# epoch: 4, train_mse: 0.06651346 train_mae: 0.22340569 valid_mse: 0.06797953 valid_mae: 0.22639324
# epoch: 5, train_mse: 0.05691029 train_mae: 0.19762313 valid_mse: 0.05855704 valid_mae: 0.20063794
# epoch: 6, train_mse: 0.02629563 train_mae: 0.12625542 valid_mse: 0.02659723 valid_mae: 0.12536252
# epoch: 7, train_mse: 0.01358372 train_mae: 0.08950988 valid_mse: 0.01424534 valid_mae: 0.09174012
# epoch: 8, train_mse: 0.00798887 train_mae: 0.07042461 valid_mse: 0.00831953 valid_mae: 0.07102957
# epoch: 9, train_mse: 0.00792694 train_mae: 0.06958446 valid_mse: 0.00825869 valid_mae: 0.07075113
# epoch: 10, train_mse: 0.00660995 train_mae: 0.06399383 valid_mse: 0.00684578 valid_mae: 0.06523947
# epoch: 11, train_mse: 0.00704376 train_mae: 0.06597118 valid_mse: 0.00734461 valid_mae: 0.06768564
# epoch: 12, train_mse: 0.00703025 train_mae: 0.06497181 valid_mse: 0.00725700 valid_mae: 0.06563786
# epoch: 13, train_mse: 0.00629777 train_mae: 0.06187792 valid_mse: 0.00650277 valid_mae: 0.06304704
# epoch: 14, train_mse: 0.00574263 train_mae: 0.05904879 valid_mse: 0.00592856 valid_mae: 0.05940343
# epoch: 15, train_mse: 0.00573978 train_mae: 0.05951362 valid_mse: 0.00578562 valid_mae: 0.05968618
# epoch: 16, train_mse: 0.00492826 train_mae: 0.05536389 valid_mse: 0.00500679 valid_mae: 0.05496912
# epoch: 17, train_mse: 0.00430871 train_mae: 0.05205167 valid_mse: 0.00442734 valid_mae: 0.05217831
# epoch: 18, train_mse: 0.00339982 train_mae: 0.04610980 valid_mse: 0.00350189 valid_mae: 0.04613405
# epoch: 19, train_mse: 0.00258445 train_mae: 0.04006772 valid_mse: 0.00275379 valid_mae: 0.04116884
# epoch: 20, train_mse: 0.00204128 train_mae: 0.03603178 valid_mse: 0.00202536 valid_mae: 0.03586134
# epoch: 21, train_mse: 0.00178673 train_mae: 0.03364168 valid_mse: 0.00188773 valid_mae: 0.03440752
# epoch: 22, train_mse: 0.00175598 train_mae: 0.03363422 valid_mse: 0.00187468 valid_mae: 0.03433130
# epoch: 23, train_mse: 0.00151198 train_mae: 0.03124889 valid_mse: 0.00160144 valid_mae: 0.03204453
# epoch: 24, train_mse: 0.00161513 train_mae: 0.03228454 valid_mse: 0.00165158 valid_mae: 0.03191580
# epoch: 25, train_mse: 0.00152870 train_mae: 0.03148607 valid_mse: 0.00156770 valid_mae: 0.03120038
# --------------------------------------
# Scoring the model.
# train:mse 0.00152870
# train:mae 0.03148607
# valid:mse 0.00156770
# valid:mae 0.03120038
# --------------------------------------
# 2024-08-07 13:31:45,375 sagemaker-training-toolkit INFO     Waiting for the process to finish and give a return code.
# 2024-08-07 13:31:45,375 sagemaker-training-toolkit INFO     Done waiting for a return code. Received 0 from exiting process.
# 2024-08-07 13:31:45,375 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2024-08-07 13:31:50 Uploading - Uploading generated training model
# 2024-08-07 13:32:04 Completed - Training job completed
# Training seconds: 291
# Billable seconds: 291

# %% [markdown]
# See this [blog-post](https://aws.amazon.com/blogs/machine-learning/easily-monitor-and-visualize-metrics-while-training-models-on-amazon-sagemaker/) for more information how to visualize metrics during the process. You can also open the training job from [Amazon SageMaker console](https://console.aws.amazon.com/sagemaker/home?#/jobs/) and monitor the metrics/logs in **Monitor** section.

# %% [markdown]
# You can use the model artifacts generated by the training job to continue training the model on the same dataset or to fine-tune the model on a different dataset (**incremental training**). You still need to provide all the hyperparameters to the estimator, but the training job will only use the sequence stride, learning rate decay factor, batch size and number of epochs, while it will overwrite all the other hyperparameters with the ones saved in the pre-trained model checkpoint.

# %%
estimator = sagemaker.algorithm.AlgorithmEstimator(
    model_uri=f's3://{bucket}/{estimator.latest_training_job.name}/output/model.tar.gz',
    algorithm_arn=algo_arn,
    base_job_name="rnn-fine-tuning",
    role=role,
    instance_count=1,
    instance_type=instance_type,
    input_mode="File",
    sagemaker_session=sagemaker_session,
    hyperparameters=hyperparameters,
    metric_definitions=metric_definitions
)

estimator.fit({"training": training_data, "validation": validation_data})
# Out:
# INFO:sagemaker:Creating training-job with name: rnn-fine-tuning-2024-08-07-13-32-42-172
# 2024-08-07 13:32:42 Starting - Starting the training job...
# 2024-08-07 13:32:59 Starting - Preparing the instances for training...
# 2024-08-07 13:33:37 Downloading - Downloading the training image..................
# 2024-08-07 13:36:34 Training - Training image download completed. Training in progress...bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2024-08-07 13:36:53,217 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2024-08-07 13:36:53,217 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:36:53,218 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:36:53,218 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:36:53,218 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:36:53,229 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2024-08-07 13:36:53,231 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2024-08-07 13:36:54,658 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:36:54,658 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:36:54,659 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:36:54,659 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:36:54,670 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:36:54,671 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:36:54,671 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:36:54,671 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:36:54,683 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2024-08-07 13:36:54,683 sagemaker-training-toolkit INFO     No Neurons detected (normal if no neurons installed)
# 2024-08-07 13:36:54,684 sagemaker-training-toolkit INFO     Failed to parse hyperparameter activation value lecun to Json.
# Returning the value itself
# 2024-08-07 13:36:54,684 sagemaker-training-toolkit INFO     Failed to parse hyperparameter cell-type value gru to Json.
# Returning the value itself
# 2024-08-07 13:36:54,695 sagemaker-training-toolkit INFO     Invoking user script
# Training Env:
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "model": "/opt/ml/input/data/model",
#         "training": "/opt/ml/input/data/training",
#         "validation": "/opt/ml/input/data/validation"
#     },
#     "current_host": "algo-1",
#     "current_instance_group": "homogeneousCluster",
#     "current_instance_group_hosts": [
#         "algo-1"
#     ],
#     "current_instance_type": "ml.m5.2xlarge",
#     "distribution_hosts": [],
#     "distribution_instance_groups": [],
#     "framework_module": "sagemaker_pytorch_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "activation": "lecun",
#         "batch-size": 64,
#         "cell-type": "gru",
#         "context-length": 200,
#         "dropout": 0.0,
#         "epochs": 25,
#         "hidden-size-1": 128,
#         "hidden-size-2": 64,
#         "hidden-size-3": 0,
#         "lr": 0.001,
#         "lr-decay": 0.999,
#         "prediction-length": 100,
#         "sequence-stride": 1
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "model": {
#             "ContentType": "application/x-sagemaker-model",
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         },
#         "validation": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "instance_groups": [
#         "homogeneousCluster"
#     ],
#     "instance_groups_dict": {
#         "homogeneousCluster": {
#             "instance_group_name": "homogeneousCluster",
#             "instance_type": "ml.m5.2xlarge",
#             "hosts": [
#                 "algo-1"
#             ]
#         }
#     },
#     "is_hetero": false,
#     "is_master": true,
#     "is_modelparallel_enabled": null,
#     "is_smddpmprun_installed": false,
#     "is_smddprun_installed": true,
#     "job_name": "rnn-fine-tuning-2024-08-07-13-32-42-172",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "/opt/ml/code",
#     "module_name": "training",
#     "network_interface_name": "eth0",
#     "num_cpus": 8,
#     "num_gpus": 0,
#     "num_neurons": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "current_instance_type": "ml.m5.2xlarge",
#         "current_group_name": "homogeneousCluster",
#         "hosts": [
#             "algo-1"
#         ],
#         "instance_groups": [
#             {
#                 "instance_group_name": "homogeneousCluster",
#                 "instance_type": "ml.m5.2xlarge",
#                 "hosts": [
#                     "algo-1"
#                 ]
#             }
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "training.py"
# }
# Environment variables:
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"activation":"lecun","batch-size":64,"cell-type":"gru","context-length":200,"dropout":0.0,"epochs":25,"hidden-size-1":128,"hidden-size-2":64,"hidden-size-3":0,"lr":0.001,"lr-decay":0.999,"prediction-length":100,"sequence-stride":1}
# SM_USER_ENTRY_POINT=training.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"model":{"ContentType":"application/x-sagemaker-model","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["model","training","validation"]
# SM_CURRENT_HOST=algo-1
# SM_CURRENT_INSTANCE_TYPE=ml.m5.2xlarge
# SM_CURRENT_INSTANCE_GROUP=homogeneousCluster
# SM_CURRENT_INSTANCE_GROUP_HOSTS=["algo-1"]
# SM_INSTANCE_GROUPS=["homogeneousCluster"]
# SM_INSTANCE_GROUPS_DICT={"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}}
# SM_DISTRIBUTION_INSTANCE_GROUPS=[]
# SM_IS_HETERO=false
# SM_MODULE_NAME=training
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_pytorch_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=8
# SM_NUM_GPUS=0
# SM_NUM_NEURONS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=/opt/ml/code
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"model":"/opt/ml/input/data/model","training":"/opt/ml/input/data/training","validation":"/opt/ml/input/data/validation"},"current_host":"algo-1","current_instance_group":"homogeneousCluster","current_instance_group_hosts":["algo-1"],"current_instance_type":"ml.m5.2xlarge","distribution_hosts":[],"distribution_instance_groups":[],"framework_module":"sagemaker_pytorch_container.training:main","hosts":["algo-1"],"hyperparameters":{"activation":"lecun","batch-size":64,"cell-type":"gru","context-length":200,"dropout":0.0,"epochs":25,"hidden-size-1":128,"hidden-size-2":64,"hidden-size-3":0,"lr":0.001,"lr-decay":0.999,"prediction-length":100,"sequence-stride":1},"input_config_dir":"/opt/ml/input/config","input_data_config":{"model":{"ContentType":"application/x-sagemaker-model","RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"},"validation":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","instance_groups":["homogeneousCluster"],"instance_groups_dict":{"homogeneousCluster":{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}},"is_hetero":false,"is_master":true,"is_modelparallel_enabled":null,"is_smddpmprun_installed":false,"is_smddprun_installed":true,"job_name":"rnn-fine-tuning-2024-08-07-13-32-42-172","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"/opt/ml/code","module_name":"training","network_interface_name":"eth0","num_cpus":8,"num_gpus":0,"num_neurons":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_group_name":"homogeneousCluster","current_host":"algo-1","current_instance_type":"ml.m5.2xlarge","hosts":["algo-1"],"instance_groups":[{"hosts":["algo-1"],"instance_group_name":"homogeneousCluster","instance_type":"ml.m5.2xlarge"}],"network_interface_name":"eth0"},"user_entry_point":"training.py"}
# SM_USER_ARGS=["--activation","lecun","--batch-size","64","--cell-type","gru","--context-length","200","--dropout","0.0","--epochs","25","--hidden-size-1","128","--hidden-size-2","64","--hidden-size-3","0","--lr","0.001","--lr-decay","0.999","--prediction-length","100","--sequence-stride","1"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_MODEL=/opt/ml/input/data/model
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_CHANNEL_VALIDATION=/opt/ml/input/data/validation
# SM_HP_ACTIVATION=lecun
# SM_HP_BATCH-SIZE=64
# SM_HP_CELL-TYPE=gru
# SM_HP_CONTEXT-LENGTH=200
# SM_HP_DROPOUT=0.0
# SM_HP_EPOCHS=25
# SM_HP_HIDDEN-SIZE-1=128
# SM_HP_HIDDEN-SIZE-2=64
# SM_HP_HIDDEN-SIZE-3=0
# SM_HP_LR=0.001
# SM_HP_LR-DECAY=0.999
# SM_HP_PREDICTION-LENGTH=100
# SM_HP_SEQUENCE-STRIDE=1
# PYTHONPATH=/opt/ml/code:/opt/conda/bin:/opt/conda/lib/python310.zip:/opt/conda/lib/python3.10:/opt/conda/lib/python3.10/lib-dynload:/opt/conda/lib/python3.10/site-packages
# Invoking script with the following command:
# /opt/conda/bin/python3.10 training.py --activation lecun --batch-size 64 --cell-type gru --context-length 200 --dropout 0.0 --epochs 25 --hidden-size-1 128 --hidden-size-2 64 --hidden-size-3 0 --lr 0.001 --lr-decay 0.999 --prediction-length 100 --sequence-stride 1
# 2024-08-07 13:36:54,695 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker Debugger as it is not installed.
# 2024-08-07 13:36:54,695 sagemaker-training-toolkit INFO     Exceptions not imported for SageMaker TF as Tensorflow is not installed.
# --------------------------------------
# Loading the pre-trained model.
# Number of parameters: 114704
# --------------------------------------
# --------------------------------------
# Initial learning rate: 0.0009752977125970467
# --------------------------------------
# --------------------------------------
# Training on 1000 samples.
# --------------------------------------
# --------------------------------------
# Features: ['x1', 'x2']
# Targets: ['y1', 'y2']
# --------------------------------------
# --------------------------------------
# Validating on 500 samples.
# --------------------------------------
# --------------------------------------
# Training the model.
# epoch: 1 train_mse: 0.00153566 train_mae: 0.03133887 valid_mse: 0.00152705 valid_mae: 0.03114194
# epoch: 2 train_mse: 0.00147297 train_mae: 0.03077449 valid_mse: 0.00151135 valid_mae: 0.03069983
# epoch: 3 train_mse: 0.00144956 train_mae: 0.03036018 valid_mse: 0.00158792 valid_mae: 0.03172555
# epoch: 4 train_mse: 0.00144653 train_mae: 0.03028867 valid_mse: 0.00152420 valid_mae: 0.03080411
# epoch: 5 train_mse: 0.00145876 train_mae: 0.03039193 valid_mse: 0.00139873 valid_mae: 0.02936186
# epoch: 6 train_mse: 0.00143869 train_mae: 0.03045802 valid_mse: 0.00146978 valid_mae: 0.03061086
# epoch: 7 train_mse: 0.00141724 train_mae: 0.03014339 valid_mse: 0.00151160 valid_mae: 0.03047478
# epoch: 8 train_mse: 0.00148955 train_mae: 0.03097987 valid_mse: 0.00148900 valid_mae: 0.03030501
# epoch: 9 train_mse: 0.00156895 train_mae: 0.03161867 valid_mse: 0.00154825 valid_mae: 0.03089862
# epoch: 10 train_mse: 0.00152262 train_mae: 0.03127950 valid_mse: 0.00152440 valid_mae: 0.03042256
# epoch: 11 train_mse: 0.00143630 train_mae: 0.03030489 valid_mse: 0.00157901 valid_mae: 0.03118368
# epoch: 12 train_mse: 0.00140836 train_mae: 0.02976924 valid_mse: 0.00142539 valid_mae: 0.02995046
# epoch: 13 train_mse: 0.00144170 train_mae: 0.03036432 valid_mse: 0.00145521 valid_mae: 0.03030636
# epoch: 14 train_mse: 0.00140302 train_mae: 0.02996100 valid_mse: 0.00144524 valid_mae: 0.02989912
# epoch: 15 train_mse: 0.00142339 train_mae: 0.03026915 valid_mse: 0.00142215 valid_mae: 0.02993839
# epoch: 16 train_mse: 0.00141374 train_mae: 0.03021104 valid_mse: 0.00144664 valid_mae: 0.02971487
# epoch: 17 train_mse: 0.00142293 train_mae: 0.03023254 valid_mse: 0.00150747 valid_mae: 0.03063052
# epoch: 18 train_mse: 0.00139132 train_mae: 0.02980378 valid_mse: 0.00148620 valid_mae: 0.03033953
# epoch: 19 train_mse: 0.00139278 train_mae: 0.02988430 valid_mse: 0.00143006 valid_mae: 0.02973282
# epoch: 20 train_mse: 0.00149851 train_mae: 0.03100230 valid_mse: 0.00146679 valid_mae: 0.03019197
# epoch: 21 train_mse: 0.00149782 train_mae: 0.03096382 valid_mse: 0.00153023 valid_mae: 0.03113141
# epoch: 22 train_mse: 0.00147689 train_mae: 0.03077785 valid_mse: 0.00152001 valid_mae: 0.03091950
# epoch: 23 train_mse: 0.00152839 train_mae: 0.03117584 valid_mse: 0.00144006 valid_mae: 0.02969836
# epoch: 24 train_mse: 0.00138709 train_mae: 0.02971376 valid_mse: 0.00145155 valid_mae: 0.03002615
# epoch: 25 train_mse: 0.00143891 train_mae: 0.03054854 valid_mse: 0.00151484 valid_mae: 0.03026690
# --------------------------------------
# Scoring the model.
# train:mse 0.00143891
# train:mae 0.03054854
# valid:mse 0.00151484
# valid:mae 0.03026690
# --------------------------------------
# 2024-08-07 13:37:51,967 sagemaker-training-toolkit INFO     Waiting for the process to finish and give a return code.
# 2024-08-07 13:37:51,967 sagemaker-training-toolkit INFO     Done waiting for a return code. Received 0 from exiting process.
# 2024-08-07 13:37:51,967 sagemaker-training-toolkit INFO     Reporting training SUCCESS
#
# 2024-08-07 13:38:08 Uploading - Uploading generated training model
# 2024-08-07 13:38:08 Completed - Training job completed
# Training seconds: 285
# Billable seconds: 285

# %% [markdown]
# ## 4. Deploy model and verify results

# %% [markdown]
# Now you can deploy the model for performing real-time inference.

# %%
serializer = sagemaker.serializers.CSVSerializer(content_type="text/csv")
deserializer = sagemaker.base_deserializers.PandasDeserializer(accept="text/csv")

# %% [markdown]
# ### A. Deploy trained model

# %%
predictor = estimator.deploy(
    initial_instance_count=1,
    instance_type=instance_type,
    model_name=f"rnn-model-{datetime.datetime.now().strftime(format='%Y-%m-%d-%H-%M-%S-%f')}",
    endpoint_name=f"rnn-endpoint-{datetime.datetime.now().strftime(format='%Y-%m-%d-%H-%M-%S-%f')}",
)
# Out:
# INFO:sagemaker:Creating model package with name: rnn-model-2024-08-07-13-38-26-026964
# ...........
# INFO:sagemaker:Creating model with name: rnn-model-2024-08-07-13-38-26-026964
# INFO:sagemaker:Creating endpoint-config with name rnn-endpoint-2024-08-07-13-38-26-026996
# INFO:sagemaker:Creating endpoint with name rnn-endpoint-2024-08-07-13-38-26-026996
# ----------!

# %% [markdown]
# Once the endpoint is in service, you can perform real-time inference.

# %% [markdown]
# ### B. Create input payload

# %% [markdown]
# The inference algorithm takes as input a CSV file containing the time series. The CSV file should have the same format as the one used for training.

# %% [markdown]
# **Test dataset:**

# %%
test_dataset = pd.read_csv("https://raw.githubusercontent.com/fg-research/rnn-sagemaker/master/data/inference/input/test.csv")

# %%
test_dataset.shape
# Out:
# (500, 4)

# %%
test_dataset.head()
# Out:
#          x1        x2         y1         y2
# 0 -0.124333 -0.888155  -3.611156 -21.167402
# 1 -0.124550 -0.972857  -7.578829 -21.938505
# 2 -0.071144 -1.087489  -7.008032 -19.818385
# 3 -0.165431 -0.965825  -8.733201 -16.944541
# 4 -0.330729 -0.940734 -15.859760 -17.673990

# %%
fig, axs = plt.subplots(nrows=len(test_dataset.columns), ncols=1, sharex=True, figsize=(6, 8))
for i, c in enumerate(test_dataset.columns):
    axs[i].plot(test_dataset[c], color="#7f8ea3", lw=1)
    axs[i].set_title(c, size=10)
    axs[i].set(xlabel="Time", ylabel="Value")
    axs[i].xaxis.set_tick_params(labelbottom=True)
    axs[i].tick_params(axis="both", which="major", labelsize=7)
    axs[i].tick_params(axis="both", which="minor", labelsize=7)
fig.suptitle("Test Dataset")
fig.tight_layout()
fig.show()

# %%
test_data = sagemaker_session.upload_string_as_file_body(
    body=test_dataset.to_csv(index=False),
    bucket=bucket,
    key="data/inference/input/test.csv"
)

# %%
test_data
# Out:
# 's3://sagemaker-eu-west-1-661670223746/data/inference/input/test.csv'

# %% [markdown]
# Given that the test dataset used in this experiment is relatively small, we invoke the endpoint using all the data.

# %%
payload = test_dataset.to_csv(index=False)

# %% [markdown]
# ### C. Perform real-time inference

# %%
response = sagemaker_session.sagemaker_runtime_client.invoke_endpoint(
    EndpointName=predictor.endpoint_name,
    ContentType="text/csv",
    Body=payload
)

real_time_predictions = deserializer.deserialize(response["Body"], content_type="text/csv")

# %%
response
# Out:
# {'ResponseMetadata': {'RequestId': '461c0780-f202-42fa-83a2-5b3e47e8d919',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'x-amzn-requestid': '461c0780-f202-42fa-83a2-5b3e47e8d919',
#    'x-amzn-invoked-production-variant': 'AllTraffic',
#    'date': 'Wed, 07 Aug 2024 13:44:55 GMT',
#    'content-type': 'application/json',
#    'content-length': '30925',
#    'connection': 'keep-alive'},
#   'RetryAttempts': 0},
#  'ContentType': 'application/json',
#  'InvokedProductionVariant': 'AllTraffic',
#  'Body': <botocore.response.StreamingBody at 0x7fc44138f9d0>}

# %%
real_time_results = sagemaker_session.upload_string_as_file_body(
    body=real_time_predictions.to_csv(index=False),
    bucket=bucket,
    key="data/inference/output/real-time/real_time_predictions.csv"
)

# %%
real_time_results
# Out:
# 's3://sagemaker-eu-west-1-661670223746/data/inference/output/real-time/real_time_predictions.csv'

# %% [markdown]
# ### D. Visualize output

# %% [markdown]
# The inference algorithm outputs the predicted values of the time series and the standard deviation of the predictions.
#
# **Notes:**
#
# a) The model predicts the time series sequence by sequence. For instance, if the `context-length` is set equal to 200, and the `prediction-length` is set equal to 100, then the first 200 data points (from 1 to 200) are used as input to predict the next 100 data points (from 201 to 300). As a result, the algorithm does not return the predicted values of the first 200 data points, which are set to missing in the output CSV file.
#
# b) The outputs include the out-of-sample forecasts beyond the last time step of the inputs. For instance, if the number of input samples is 500, and the `prediction-length` is 100, then the output CSV file will contain 600 samples, where the last 100 samples are the out-of-sample forecasts.

# %%
real_time_predictions.shape
# Out:
# (600, 4)

# %%
real_time_predictions.head()
# Out:
#    y1_mean  y1_std  y2_mean  y2_std
# 0      NaN     NaN      NaN     NaN
# 1      NaN     NaN      NaN     NaN
# 2      NaN     NaN      NaN     NaN
# 3      NaN     NaN      NaN     NaN
# 4      NaN     NaN      NaN     NaN

# %%
real_time_predictions.tail()
# Out:
#        y1_mean    y1_std    y2_mean    y2_std
# 595  12.420091  2.203111 -16.934319  2.144572
# 596   9.114094  2.362700 -17.546752  2.109208
# 597   6.183228  2.224022 -19.213720  2.128639
# 598   4.050130  2.165220 -18.714835  2.231286
# 599   0.926725  2.249383 -19.414488  2.163962

# %%
real_time_predictions.isna().sum(axis=0)
# Out:
# y1_mean    200
# y1_std     200
# y2_mean    200
# y2_std     200
# dtype: int64

# %%
fig, axs = plt.subplots(nrows=len([c for c in test_dataset.columns if c.startswith("y")]), ncols=1, sharex=True, figsize=(6, 5))
for i, c in enumerate([c for c in test_dataset.columns if c.startswith("y")]):
    axs[i].plot(test_dataset.index, test_dataset[c].values, color="#7f8ea3", lw=1, label="Actual" if i == 0 else None)
    axs[i].plot(real_time_predictions.index, real_time_predictions[f"{c}_mean"].values, color="#009ad3", lw=1, label="Predicted" if i == 0 else None)
    axs[i].fill_between(real_time_predictions.index, real_time_predictions[f"{c}_mean"].values + real_time_predictions[f"{c}_std"].values, real_time_predictions[f"{c}_mean"].values - real_time_predictions[f"{c}_std"].values, color="#009ad3", alpha=0.2, lw=1, label="Predicted +/- 1 Std. Dev." if i == 0 else None)
    axs[i].fill_between(real_time_predictions.index, real_time_predictions[f"{c}_mean"].values + 2 * real_time_predictions[f"{c}_std"].values, real_time_predictions[f"{c}_mean"].values - 2 * real_time_predictions[f"{c}_std"].values, color="#009ad3", alpha=0.1, lw=1, label="Predicted +/- 2 Std. Dev." if i == 0 else None)
    axs[i].set_title(c, size=10)
    axs[i].set(xlabel="Time", ylabel="Value")
    axs[i].xaxis.set_tick_params(labelbottom=True)
    axs[i].tick_params(axis="both", which="major", labelsize=7)
    axs[i].tick_params(axis="both", which="minor", labelsize=7)
fig.suptitle("Real Time Predictions on Test Dataset")
fig.legend(bbox_to_anchor=(1, 0, 0.4, 1), frameon=False)
fig.tight_layout()
fig.show()

# %% [markdown]
# ### E. Calculate relevant metrics

# %% [markdown]
# In this section we assess the model's forecasting performance against the ground truth time series values. Note that in this section we calculate the mean squared error (MSE) and mean absolute error (MAE) separately for each time series using unscaled data. These are different from the metrics returned by the algorithm, which are the average MSE and MAE across all time series calculated using scaled data.

# %%
for c in [c for c in test_dataset.columns if c.startswith("y")]:
    mse = mean_squared_error(test_dataset[c].iloc[context_length:], real_time_predictions[f"{c}_mean"].iloc[context_length: - prediction_length])
    mae = mean_absolute_error(test_dataset[c].iloc[context_length:], real_time_predictions[f"{c}_mean"].iloc[context_length: -prediction_length])
    print(f"Time series: {c}, MSE: {format(mse, '.2f')}, MAE: {format(mae, '.2f')}")
# Out:
# Time series: y1, MSE: 5.60, MAE: 1.94
# Time series: y2, MSE: 4.11, MAE: 1.64

# %% [markdown]
# If [Amazon SageMaker Model Monitor](https://docs.aws.amazon.com/sagemaker/latest/dg/model-monitor.html) supports the type of problem you are trying to solve using this algorithm, use the following examples to add Model Monitor support to your product.
# For sample code to enable and monitor the model, see following notebooks:
# 1. [Enable Amazon SageMaker Model Monitor](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker_model_monitor/enable_model_monitor/SageMaker-Enable-Model-Monitor.ipynb)
# 2. [Amazon SageMaker Model Monitor - visualizing monitoring results](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/sagemaker_model_monitor/visualization/SageMaker-Model-Monitor-Visualize.ipynb)

# %% [markdown]
# ### F. Delete the endpoint

# %% [markdown]
# Now that you have successfully performed a real-time inference, you do not need the endpoint any more. You can terminate the same to avoid being charged.

# %%
predictor.delete_model()
predictor.delete_endpoint(delete_endpoint_config=True)
# Out:
# INFO:sagemaker:Deleting model with name: rnn-model-2024-08-07-13-38-26-026964
# INFO:sagemaker:Deleting endpoint configuration with name: rnn-endpoint-2024-08-07-13-38-26-026996
# INFO:sagemaker:Deleting endpoint with name: rnn-endpoint-2024-08-07-13-38-26-026996

# %% [markdown]
# Since this is an experiment, you do not need to run a hyperparameter tuning job. However, if you would like to see how to tune a model trained using a third-party algorithm with Amazon SageMaker's hyperparameter tuning functionality, you can run the optional tuning step.

# %% [markdown]
# ## 5. Tune your model! (optional)

# %% [markdown]
# ### A. Tuning Guidelines

# %% [markdown]
# The model has the following hyperparameters, all of which are tunable:
# - `context-length`: `int`. The length of the input sequences.
# - `prediction-length`: `int`. The length of the output sequences.
# - `sequence-stride`: `int`. The period between consecutive output sequences.
# - `cell-type`: `str`. The type of RNN cell used by each layer.
# - `hidden-size-1`: `str`. The number of hidden units of the first layer.
# - `hidden-size-2`: `str`. The number of hidden units of the second layer.
# - `hidden-size-3`: `str`. The number of hidden units of the third layer.
# - `activation`: `str`. The activation function applied after each layer.
# - `dropout`: `float`. The dropout rate applied after each layer.
# - `lr`: `float`. The learning rate used for training.
# - `lr-decay`: `float`. The decay factor applied to the learning rate.
# - `batch-size`: `int`. The batch size used for training.
# - `epochs`: `int`. The number of training epochs.

# %% [markdown]
# **Note:** While the first layer needs to be always included, the second and third layer can be excluded by setting the number of hidden units equal to zero. For instance,
# * if `hidden-size-1 = 100`, `hidden-size-2 = 50` and `hidden-size-3 = 25`, then the algorithm will train a model with three layers with respectively 100, 50 and 25 units,
# * if `hidden-size-1 = 100`, `hidden-size-2 = 50` and `hidden-size-3 = 0`, then the algorithm will train a model with two layers with respectively 100 and 50 units,
# * if `hidden-size-1 = 100`, `hidden-size-2 = 0` and `hidden-size-3 = 0`, then the algorithm will train a model with only one layer with 100 units.

# %% [markdown]
# ### B. Define Tuning configuration

# %%
hyperparameter_ranges = {
    "hidden-size-1": sagemaker.parameter.CategoricalParameter([64, 128, 256]),
    "hidden-size-2": sagemaker.parameter.CategoricalParameter([32, 64, 128]),
    "hidden-size-3": sagemaker.parameter.CategoricalParameter([0, 16, 32, 64]),
    "cell-type": sagemaker.parameter.CategoricalParameter(["lstm", "gru"]),
    "activation": sagemaker.parameter.CategoricalParameter(["silu", "relu", "tanh", "gelu", "lecun", "linear"]),
    "dropout": sagemaker.parameter.ContinuousParameter(0, 0.5),
    "lr": sagemaker.parameter.ContinuousParameter(0.0001, 0.01),
    "lr-decay": sagemaker.parameter.ContinuousParameter(0.9, 1.0),
    "batch-size": sagemaker.parameter.CategoricalParameter([32, 64, 128, 256]),
    "epochs": sagemaker.parameter.IntegerParameter(10, 100),
}

# %% [markdown]
# We use the validation mean absolute error (MAE) as the objective to be minimized.

# %%
objective_metric_name = "valid_mae"

# %%
objective_type = "Minimize"

# %% [markdown]
# ### C. Run a model tuning job

# %% [markdown]
# Make sure to detach the pre-trained model before tuning, otherwise the algorithm will keep using the same hyperparameters with the exception of the batch size, learning rate decay factor and number of epochs.

# %%
estimator.model_uri = None

# %% [markdown]
# In the interest of time, we run the tuner only for a few iterations.

# %%
tuner = sagemaker.tuner.HyperparameterTuner(
    estimator=estimator,
    base_tuning_job_name="rnn-tuning",
    objective_metric_name=objective_metric_name,
    objective_type=objective_type,
    hyperparameter_ranges=hyperparameter_ranges,
    max_jobs=8,
    max_parallel_jobs=4,
    random_seed=100,
)

# %%
tuner.fit({"training": training_data, "validation": validation_data})
# Out:
# INFO:sagemaker:Creating hyperparameter tuning job with name: rnn-tuning-240807-1344
# ..............................................................................................................................................................................................!

# %%
tuner.analytics().dataframe().sort_values(by="FinalObjectiveValue", ascending=True, ignore_index=True)
# Out:
#   activation  batch-size cell-type   dropout  epochs  hidden-size-1  \
# 0      lecun       128.0       gru  0.112467    47.0          128.0
# 1     linear       256.0       gru  0.000000    24.0          128.0
# 2     linear       256.0       gru  0.273129    85.0          256.0
# 3       silu        32.0       gru  0.078974    22.0          128.0
# 4       silu        32.0       gru  0.186710    98.0          128.0
# 5      lecun        32.0      lstm  0.494782    60.0          256.0
# 6      lecun       128.0      lstm  0.063618    44.0          128.0
# 7       gelu       256.0      lstm  0.124774    42.0          128.0
#
#    hidden-size-2  hidden-size-3        lr  lr-decay  \
# 0           64.0            0.0  0.002450  0.981595
# 1           32.0           32.0  0.010000  0.987465
# 2           32.0           32.0  0.003081  0.971489
# 3           32.0           64.0  0.002865  0.919055
# 4           32.0           32.0  0.001890  0.910550
# 5           32.0           64.0  0.000346  0.976463
# 6           64.0            0.0  0.000100  0.995510
# 7           64.0           16.0  0.000195  0.906963
#
#                        TrainingJobName TrainingJobStatus  FinalObjectiveValue  \
# 0  rnn-tuning-240807-1344-005-04d5cd9c         Completed             0.030301
# 1  rnn-tuning-240807-1344-007-d1cc4c7f         Completed             0.034932
# 2  rnn-tuning-240807-1344-004-c0f81dcb         Completed             0.049631
# 3  rnn-tuning-240807-1344-001-c708c8da         Completed             0.067410
# 4  rnn-tuning-240807-1344-006-a435dce5         Completed             0.072688
# 5  rnn-tuning-240807-1344-003-9798001f         Completed             0.081019
# 6  rnn-tuning-240807-1344-008-3bc78453         Completed             0.213372
# 7  rnn-tuning-240807-1344-002-d5ba0e4a         Completed             0.475829
#
#           TrainingStartTime           TrainingEndTime  \
# 0 2024-08-07 13:51:31+00:00 2024-08-07 13:53:28+00:00
# 1 2024-08-07 13:53:13+00:00 2024-08-07 13:54:22+00:00
# 2 2024-08-07 13:45:48+00:00 2024-08-07 13:52:43+00:00
# 3 2024-08-07 13:45:41+00:00 2024-08-07 13:51:06+00:00
# 4 2024-08-07 13:52:24+00:00 2024-08-07 13:59:59+00:00
# 5 2024-08-07 13:45:42+00:00 2024-08-07 13:51:52+00:00
# 6 2024-08-07 13:53:45+00:00 2024-08-07 13:55:59+00:00
# 7 2024-08-07 13:45:50+00:00 2024-08-07 13:55:21+00:00
#
#    TrainingElapsedTimeSeconds
# 0                       117.0
# 1                        69.0
# 2                       415.0
# 3                       325.0
# 4                       455.0
# 5                       370.0
# 6                       134.0
# 7                       571.0

# %%
tuning_job_result = sagemaker_session.sagemaker_client.describe_hyper_parameter_tuning_job(
    HyperParameterTuningJobName=tuner.latest_tuning_job.name
)

# %%
print("Best hyperparameters:")
tuning_job_result["BestTrainingJob"]["TunedHyperParameters"]
# Out:
# Best hyperparameters:
# {'activation': 'lecun',
#  'batch-size': '128',
#  'cell-type': 'gru',
#  'dropout': '0.11246650672591241',
#  'epochs': '47',
#  'hidden-size-1': '128',
#  'hidden-size-2': '64',
#  'hidden-size-3': '0',
#  'lr': '0.002450268550741182',
#  'lr-decay': '0.9815951268134225'}

# %%
print("Best score:")
tuning_job_result["BestTrainingJob"]["FinalHyperParameterTuningJobObjectiveMetric"]["Value"]
# Out:
# Best score:
# 0.030301159247756004

# %% [markdown]
# Once you have completed a tuning job (or even while the job is still running), you can [clone and use this notebook](https://github.com/awslabs/amazon-sagemaker-examples/blob/master/hyperparameter_tuning/analyze_results/HPO_Analyze_TuningJob_Results.ipynb) to analyze the results to understand how each hyperparameter effects the quality of the model.

# %% [markdown]
# ## 6. Perform Batch inference

# %% [markdown]
# In this section, you will perform batch inference.

# %%
transformer = estimator.transformer(
    instance_count=1,
    instance_type=instance_type,
)
# Out:
# INFO:sagemaker:Creating model package with name: rnn-tsf-v1-0-2024-08-07-14-01-13-272
# .........
# INFO:sagemaker:Creating model with name: rnn-tsf-v1-0-2024-08-07-14-01-13-272-2024-08-07-14-01-58-760

# %%
transformer.base_transform_job_name = "rnn-transform"

# %%
transformer.transform(
    data=test_data,
    content_type="text/csv",
)
# Out:
# INFO:sagemaker:Creating transform job with name: rnn-transform-2024-08-07-14-02-03-755
# ..............................................Warning: TorchServe is using non-default JVM parameters: -XX:-UseContainerSupport
# WARNING: sun.reflect.Reflection.getCallerClass is not supported. This will impact performance.
# 2024-08-07T14:09:44,433 [WARN ] main org.pytorch.serve.util.ConfigManager - Your torchserve instance can access any URL to load models. When deploying to production, make sure to limit the set of allowed_urls in config.properties
# 2024-08-07T14:09:44,436 [INFO ] main org.pytorch.serve.servingsdk.impl.PluginsManager - Initializing plugins manager...
# 2024-08-07T14:09:44,493 [INFO ] main org.pytorch.serve.metrics.configuration.MetricConfiguration - Successfully loaded metrics configuration from /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml
# 2024-08-07T14:09:44,613 [INFO ] main org.pytorch.serve.ModelServer -
# Torchserve version: 0.11.0
# TS Home: /opt/conda/lib/python3.10/site-packages
# Current directory: /
# Temp directory: /home/model-server/tmp
# Metrics config path: /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml
# Number of GPUs: 0
# Number of CPUs: 8
# Max heap size: 7840 M
# Python executable: /opt/conda/bin/python3.10
# Config file: /etc/sagemaker-ts.properties
# Inference address: http://0.0.0.0:8080
# Management address: http://0.0.0.0:8080
# Metrics address: http://127.0.0.1:8082
# Model Store: /.sagemaker/ts/models
# Initial Models: model=/opt/ml/model
# Log dir: /logs
# Metrics dir: /logs
# Netty threads: 0
# Netty client threads: 0
# Default workers per model: 8
# Blacklist Regex: N/A
# Maximum Response Size: 6553500
# Maximum Request Size: 6553500
# Limit Maximum Image Pixels: true
# Prefer direct buffer: false
# Allowed Urls: [file://.*|http(s)?://.*]
# Custom python dependency for model allowed: false
# Enable metrics API: true
# Metrics mode: LOG
# Disable system metrics: true
# Workflow Store: /.sagemaker/ts/models
# CPP log config: N/A
# Model config: N/A
# System metrics command: default
# 2024-08-07T14:09:44,621 [INFO ] main org.pytorch.serve.servingsdk.impl.PluginsManager -  Loading snapshot serializer plugin...
# 2024-08-07T14:09:44,640 [INFO ] main org.pytorch.serve.ModelServer - Loading initial models: /opt/ml/model
# 2024-08-07T14:09:44,649 [INFO ] main org.pytorch.serve.archive.model.ModelArchive - createTempDir /home/model-server/tmp/models/ed440281959241339ea37d4340197754
# 2024-08-07T14:09:44,649 [INFO ] main org.pytorch.serve.archive.model.ModelArchive - createSymbolicDir /home/model-server/tmp/models/ed440281959241339ea37d4340197754/model
# 2024-08-07T14:09:44,650 [WARN ] main org.pytorch.serve.archive.model.ModelArchive - Model archive version is not defined. Please upgrade to torch-model-archiver 0.2.0 or higher
# 2024-08-07T14:09:44,650 [WARN ] main org.pytorch.serve.archive.model.ModelArchive - Model archive createdOn is not defined. Please upgrade to torch-model-archiver 0.2.0 or higher
# 2024-08-07T14:09:44,652 [INFO ] main org.pytorch.serve.wlm.ModelManager - Model model loaded.
# 2024-08-07T14:09:44,664 [INFO ] main org.pytorch.serve.ModelServer - Initialize Inference server with: EpollServerSocketChannel.
# 2024-08-07T14:09:44,896 [INFO ] main org.pytorch.serve.ModelServer - Inference API bind to: http://0.0.0.0:8080
# 2024-08-07T14:09:44,897 [INFO ] main org.pytorch.serve.ModelServer - Initialize Metrics server with: EpollServerSocketChannel.
# 2024-08-07T14:09:44,936 [INFO ] main org.pytorch.serve.ModelServer - Metrics API bind to: http://127.0.0.1:8082
# Model server started.
# 2024-08-07T14:09:47,434 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9005, pid=63
# 2024-08-07T14:09:47,443 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9005
# 2024-08-07T14:09:47,474 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9004, pid=68
# 2024-08-07T14:09:47,476 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9004
# 2024-08-07T14:09:47,523 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:47,524 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - [PID]63
# 2024-08-07T14:09:47,524 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:47,530 [INFO ] W-9005-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9005
# 2024-08-07T14:09:47,539 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:47,561 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9005.
# 2024-08-07T14:09:47,563 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:47,564 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - [PID]68
# 2024-08-07T14:09:47,565 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:47,565 [INFO ] W-9004-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9004
# 2024-08-07T14:09:47,567 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:47,570 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9004.
# 2024-08-07T14:09:47,578 [INFO ] W-9005-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039787577
# 2024-08-07T14:09:47,599 [INFO ] W-9004-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039787599
# 2024-08-07T14:09:47,632 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9001, pid=66
# 2024-08-07T14:09:47,636 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9001
# 2024-08-07T14:09:47,655 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:47,663 [INFO ] W-9004-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:47,679 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9000, pid=67
# 2024-08-07T14:09:47,679 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9007, pid=69
# 2024-08-07T14:09:47,684 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9007
# 2024-08-07T14:09:47,681 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9000
# 2024-08-07T14:09:47,721 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9003, pid=65
# 2024-08-07T14:09:47,723 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:47,724 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - [PID]66
# 2024-08-07T14:09:47,724 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:47,725 [INFO ] W-9001-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9001
# 2024-08-07T14:09:47,726 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:47,727 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9001.
# 2024-08-07T14:09:47,728 [INFO ] W-9001-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039787728
# 2024-08-07T14:09:47,728 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9003
# 2024-08-07T14:09:47,738 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9006, pid=64
# 2024-08-07T14:09:47,740 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9006
# 2024-08-07T14:09:47,803 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:47,805 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - [PID]69
# 2024-08-07T14:09:47,806 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:47,806 [INFO ] W-9007-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9007
# 2024-08-07T14:09:47,809 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:47,839 [INFO ] W-9001-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:47,850 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9007.
# 2024-08-07T14:09:47,850 [INFO ] W-9007-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039787850
# 2024-08-07T14:09:47,853 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:47,854 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - [PID]67
# 2024-08-07T14:09:47,855 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:47,855 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9000
# 2024-08-07T14:09:47,857 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:47,872 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039787872
# 2024-08-07T14:09:47,888 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9000.
# 2024-08-07T14:09:47,927 [INFO ] W-9000-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:47,928 [INFO ] W-9007-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:47,934 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:47,940 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - [PID]65
# 2024-08-07T14:09:47,941 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:47,941 [INFO ] W-9003-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9003
# 2024-08-07T14:09:47,945 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:47,956 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9003.
# 2024-08-07T14:09:47,957 [INFO ] W-9003-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039787957
# 2024-08-07T14:09:47,958 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:47,968 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - [PID]64
# 2024-08-07T14:09:47,969 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:47,969 [INFO ] W-9006-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9006
# 2024-08-07T14:09:47,970 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:48,000 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9006.
# 2024-08-07T14:09:48,001 [INFO ] W-9006-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039788001
# 2024-08-07T14:09:48,035 [INFO ] W-9003-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:48,067 [INFO ] W-9006-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:48,109 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - s_name_part0=/home/model-server/tmp/.ts.sock, s_name_part1=9002, pid=62
# 2024-08-07T14:09:48,111 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - Listening on port: /home/model-server/tmp/.ts.sock.9002
# 2024-08-07T14:09:48,334 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - Successfully loaded /opt/conda/lib/python3.10/site-packages/ts/configs/metrics.yaml.
# 2024-08-07T14:09:48,352 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - [PID]62
# 2024-08-07T14:09:48,353 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - Torch worker started.
# 2024-08-07T14:09:48,354 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - Python runtime: 3.10.9
# 2024-08-07T14:09:48,354 [INFO ] W-9002-model_1.0 org.pytorch.serve.wlm.WorkerThread - Connecting to: /home/model-server/tmp/.ts.sock.9002
# 2024-08-07T14:09:48,376 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - Connection accepted: /home/model-server/tmp/.ts.sock.9002.
# 2024-08-07T14:09:48,379 [INFO ] W-9002-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039788379
# 2024-08-07T14:09:48,427 [INFO ] W-9002-model_1.0-stdout MODEL_LOG - model_name: model, batchSize: 1
# 2024-08-07T14:09:48,460 [INFO ] W-9005-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 882
# 2024-08-07T14:09:48,461 [INFO ] W-9005-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:3799.0|#WorkerName:W-9005-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,464 [INFO ] W-9005-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:11.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,597 [INFO ] W-9004-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 998
# 2024-08-07T14:09:48,598 [INFO ] W-9004-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:3936.0|#WorkerName:W-9004-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,598 [INFO ] W-9004-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:30.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,657 [INFO ] W-9003-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 700
# 2024-08-07T14:09:48,658 [INFO ] W-9003-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:3997.0|#WorkerName:W-9003-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,664 [INFO ] W-9003-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:7.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,680 [INFO ] W-9000-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 807
# 2024-08-07T14:09:48,681 [INFO ] W-9000-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:4022.0|#WorkerName:W-9000-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,681 [INFO ] W-9000-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:2.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,725 [INFO ] W-9007-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 874
# 2024-08-07T14:09:48,725 [INFO ] W-9007-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:4064.0|#WorkerName:W-9007-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,725 [INFO ] W-9007-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:1.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,734 [INFO ] W-9001-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 1006
# 2024-08-07T14:09:48,735 [INFO ] W-9001-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:4075.0|#WorkerName:W-9001-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,735 [INFO ] W-9001-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:1.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,900 [INFO ] W-9006-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 899
# 2024-08-07T14:09:48,901 [INFO ] W-9006-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:4240.0|#WorkerName:W-9006-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,901 [INFO ] W-9006-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:1.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,961 [INFO ] W-9002-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 581
# 2024-08-07T14:09:48,961 [INFO ] W-9002-model_1.0 TS_METRICS - WorkerLoadTime.Milliseconds:4301.0|#WorkerName:W-9002-model_1.0,Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:48,961 [INFO ] W-9002-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:1.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039788
# 2024-08-07T14:09:50,198 [INFO ] pool-2-thread-9 ACCESS_LOG - /169.254.255.130:50078 "GET /ping HTTP/1.1" 200 10
# 2024-08-07T14:09:50,199 [INFO ] pool-2-thread-9 TS_METRICS - Requests2XX.Count:1.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50,215 [INFO ] epollEventLoopGroup-3-2 ACCESS_LOG - /169.254.255.130:50090 "GET /execution-parameters HTTP/1.1" 404 1
# 2024-08-07T14:09:50,215 [INFO ] epollEventLoopGroup-3-2 TS_METRICS - Requests4XX.Count:1.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50,256 [INFO ] epollEventLoopGroup-3-3 TS_METRICS - ts_inference_requests_total.Count:1.0|#model_name:model,model_version:default|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50,257 [INFO ] W-9005-model_1.0 org.pytorch.serve.wlm.WorkerThread - Looping backend response at: 1723039790257
# 2024-08-07T14:09:50,258 [INFO ] W-9005-model_1.0-stdout MODEL_LOG - Backend received inference at: 1723039790
# 2024-08-07T14:09:50,364 [INFO ] W-9005-model_1.0-stdout org.pytorch.serve.wlm.WorkerLifeCycle - result=[METRICS]PredictionTime.Milliseconds:105.72|#ModelName:model,Level:Model|#type:GAUGE|#hostname:a2ab1f63db01,1723039790,afa93e5e-0ce3-4f88-9ec6-7b1dc356bef7, pattern=[METRICS]
# 2024-08-07T14:09:50,366 [INFO ] W-9005-model_1.0-stdout MODEL_METRICS - PredictionTime.ms:105.72|#ModelName:model,Level:Model|#hostname:a2ab1f63db01,requestID:afa93e5e-0ce3-4f88-9ec6-7b1dc356bef7,timestamp:1723039790
# 2024-08-07T14:09:50,366 [INFO ] W-9005-model_1.0 ACCESS_LOG - /169.254.255.130:50098 "POST /invocations HTTP/1.1" 200 112
# 2024-08-07T14:09:50,367 [INFO ] W-9005-model_1.0 TS_METRICS - Requests2XX.Count:1.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50,367 [INFO ] W-9005-model_1.0 TS_METRICS - ts_inference_latency_microseconds.Microseconds:109852.337|#model_name:model,model_version:default|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50,368 [INFO ] W-9005-model_1.0 TS_METRICS - ts_queue_latency_microseconds.Microseconds:168.189|#model_name:model,model_version:default|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50,368 [INFO ] W-9005-model_1.0 TS_METRICS - QueueTime.Milliseconds:0.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50,368 [INFO ] W-9005-model_1.0 org.pytorch.serve.wlm.WorkerThread - Backend response time: 109
# 2024-08-07T14:09:50,368 [INFO ] W-9005-model_1.0 TS_METRICS - WorkerThreadTime.Milliseconds:3.0|#Level:Host|#hostname:a2ab1f63db01,timestamp:1723039790
# 2024-08-07T14:09:50.221:[sagemaker logs]: MaxConcurrentTransforms=1, MaxPayloadInMB=6, BatchStrategy=MULTI_RECORD

# %%
batch_predictions = sagemaker_session.read_s3_file(
    bucket=bucket,
    key_prefix=f"{transformer.latest_transform_job.name}/test.csv.out"
)

batch_predictions = pd.read_csv(io.StringIO(batch_predictions), dtype=float)

# %%
batch_predictions.shape
# Out:
# (600, 4)

# %%
batch_predictions.head()
# Out:
#    y1_mean  y1_std  y2_mean  y2_std
# 0      NaN     NaN      NaN     NaN
# 1      NaN     NaN      NaN     NaN
# 2      NaN     NaN      NaN     NaN
# 3      NaN     NaN      NaN     NaN
# 4      NaN     NaN      NaN     NaN

# %%
batch_predictions.tail()
# Out:
#        y1_mean    y1_std    y2_mean    y2_std
# 595  12.420091  2.203111 -16.934319  2.144572
# 596   9.114094  2.362700 -17.546752  2.109208
# 597   6.183228  2.224022 -19.213720  2.128639
# 598   4.050130  2.165220 -18.714835  2.231286
# 599   0.926725  2.249383 -19.414488  2.163962

# %%
batch_predictions.isna().sum(axis=0)
# Out:
# y1_mean    200
# y1_std     200
# y2_mean    200
# y2_std     200
# dtype: int64

# %%
np.all(np.isclose(batch_predictions.dropna().values, real_time_predictions.dropna().values))
# Out:
# True

# %%
fig, axs = plt.subplots(nrows=len([c for c in test_dataset.columns if c.startswith("y")]), ncols=1, sharex=True, figsize=(6, 5))
for i, c in enumerate([c for c in test_dataset.columns if c.startswith("y")]):
    axs[i].plot(test_dataset.index, test_dataset[c].values, color="#7f8ea3", lw=1, label="Actual" if i == 0 else None)
    axs[i].plot(batch_predictions.index, batch_predictions[f"{c}_mean"].values, color="#009ad3", lw=1, label="Predicted" if i == 0 else None)
    axs[i].fill_between(batch_predictions.index, batch_predictions[f"{c}_mean"].values + batch_predictions[f"{c}_std"].values, batch_predictions[f"{c}_mean"].values - batch_predictions[f"{c}_std"].values, color="#009ad3", alpha=0.2, lw=1, label="Predicted +/- 1 Std. Dev." if i == 0 else None)
    axs[i].fill_between(batch_predictions.index, batch_predictions[f"{c}_mean"].values + 2 * batch_predictions[f"{c}_std"].values, batch_predictions[f"{c}_mean"].values - 2 * batch_predictions[f"{c}_std"].values, color="#009ad3", alpha=0.1, lw=1, label="Predicted +/- 2 Std. Dev." if i == 0 else None)
    axs[i].set_title(c, size=10)
    axs[i].set(xlabel="Time", ylabel="Value")
    axs[i].xaxis.set_tick_params(labelbottom=True)
    axs[i].tick_params(axis="both", which="major", labelsize=7)
    axs[i].tick_params(axis="both", which="minor", labelsize=7)
fig.suptitle("Batch Predictions on Test Dataset")
fig.legend(bbox_to_anchor=(1, 0, 0.4, 1), frameon=False)
fig.tight_layout()
fig.show()

# %%
batch_results = sagemaker_session.upload_string_as_file_body(
    body=batch_predictions.to_csv(index=False),
    bucket=bucket,
    key="data/inference/output/batch/batch_predictions.csv"
)

# %%
batch_results
# Out:
# 's3://sagemaker-eu-west-1-661670223746/data/inference/output/batch/batch_predictions.csv'

# %% [markdown]
# ## 7. Clean-up

# %% [markdown]
# ### A. Delete the model

# %%
transformer.delete_model()
# Out:
# INFO:sagemaker:Deleting model with name: rnn-tsf-v1-0-2024-08-07-14-01-13-272-2024-08-07-14-01-58-760

# %% [markdown]
# ### B. Unsubscribe to the listing (optional)

# %% [markdown]
# If you would like to unsubscribe to the algorithm, follow these steps. Before you cancel the subscription, ensure that you do not have any [deployable model](https://console.aws.amazon.com/sagemaker/home#/models) created from the model package or using the algorithm. Note - You can find this information by looking at the container name associated with the model.
#
# **Steps to unsubscribe to product from AWS Marketplace**:
# 1. Navigate to __Machine Learning__ tab on [__Your Software subscriptions page__](https://aws.amazon.com/marketplace/ai/library?productType=ml&ref_=mlmp_gitdemo_indust)
# 2. Locate the listing that you want to cancel the subscription for, and then choose __Cancel Subscription__  to cancel the subscription.
